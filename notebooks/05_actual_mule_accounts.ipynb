# %%
import pandas as pd

df = pd.read_csv(
    "../data/processed/preprocessed_data.csv"
)

print(df.shape)

print(
    df[df["F3924"] == 1].index.tolist()[:20]
)
# Out:
# (9082, 3016)
# [9001, 9002, 9003, 9004, 9005, 9006, 9007, 9008, 9009, 9010, 9011, 9012, 9013, 9014, 9015, 9016, 9017, 9018, 9019, 9020]
